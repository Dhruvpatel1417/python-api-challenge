# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# !pip install citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.5.tar.gz (557 kB)
# Collecting kdtree>=0.12
#   Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559700 sha256=7f165fe9713a1e5ca7b85cd4c0ba36858f07078b6a5a4786e74ef2866373efe6
#   Stored in directory: c:\users\dhruv\appdata\local\pip\cache\wheels\6d\df\5e\ad8eb9cc5ee7f4ba76865167c09f9a7edff405c669111d8353
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#starting url for Weather Map API call
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
print(url)

#list of city data
city = []

#print to logger
print("Beginning Data Retrieval")
print("-" * 17)

# Create counters
record_count = 1
set_count = 1

#loop through all the cities in out list
for index, city in enumerate(cities):

    # Group cities in sets of 50 for logging purpose
    if (index % 50 == 0 and index >=50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url + "%q=" + city
    
    # Log the url record and set number
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    # Run an API reqest for each of the cities
    try: 
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Extract out max temp and humidity and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["Wing"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City info into city data list
        city_data.append({
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness":city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date 
        })
    except:
        print("City not found, Skiping...")
        pass
# Indicate that Data loading is complete
print("----------------")
print("Data Retrieval Complete")
print("----------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9a422fe15d02eae13b77f7d6e6b4321a
# Beginning Data Retrieval
# -----------------
# Processing Record 1 of Set 1 | thompson
# City not found, Skiping...
# Processing Record 2 of Set 1 | castro
# City not found, Skiping...
# Processing Record 3 of Set 1 | barentsburg
# City not found, Skiping...
# Processing Record 4 of Set 1 | marcona
# City not found, Skiping...
# Processing Record 5 of Set 1 | mahebourg
# City not found, Skiping...
# Processing Record 6 of Set 1 | semporna
# City not found, Skiping...
# Processing Record 7 of Set 1 | roebourne
# City not found, Skiping...
# Processing Record 8 of Set 1 | bengkulu
# City not found, Skiping...
# Processing Record 9 of Set 1 | khatanga
# City not found, Skiping...
# Processing Record 10 of Set 1 | margate
# City not found, Skiping...
# Processing Record 11 of Set 1 | adre
# City not found, Skiping...
# Processing Record 12 of Set 1 | saskylakh
# City not found, Skiping...
# Processing Record 13 of Set 1 | avarua
# City not found, Skiping...
# Processing Record 14 of Set 1 | talnakh
# City not found, Skiping...
# Processing Record 15 of Set 1 | punta arenas
# City not found, Skiping...
# Processing Record 16 of Set 1 | sisimiut
# City not found, Skiping...
# Processing Record 17 of Set 1 | karratha
# City not found, Skiping...
# Processing Record 18 of Set 1 | tabou
# City not found, Skiping...
# Processing Record 19 of Set 1 | jamestown
# City not found, Skiping...
# Processing Record 20 of Set 1 | salvador
# City not found, Skiping...
# Processing Record 21 of Set 1 | acapulco
# City not found, Skiping...
# Processing Record 22 of Set 1 | cherskiy
# City not found, Skiping...
# Processing Record 23 of Set 1 | new norfolk
# City not found, Skiping...
# Processing Record 24 of Set 1 | sao joao da barra
# City not found, Skiping...
# Processing Record 25 of Set 1 | severo-kurilsk
# City not found, Skiping...
# Processing Record 26 of Set 1 | torbay
# City not found, Skiping...
# Processing Record 27 of Set 1 | kiama
# City not found, Skiping...
# Processing Record 28 of Set 1 | ponta do sol
# City not found, Skiping...
# Processing Record 29 of Set 1 | bredasdorp
# City not found, Skiping...
# Processing Record 30 of Set 1 | tumaco
# City not found, Skiping...
# Processing Record 31 of Set 1 | portland
# City not found, Skiping...
# Processing Record 32 of Set 1 | vaini
# City not found, Skiping...
# Processing Record 33 of Set 1 | busselton
# City not found, Skiping...
# Processing Record 34 of Set 1 | qaqortoq
# City not found, Skiping...
# Processing Record 35 of Set 1 | carnarvon
# City not found, Skiping...
# Processing Record 36 of Set 1 | santa cruz
# City not found, Skiping...
# Processing Record 37 of Set 1 | albany
# City not found, Skiping...
# Processing Record 38 of Set 1 | yarada
# City not found, Skiping...
# Processing Record 39 of Set 1 | belushya guba
# City not found, Skiping...
# Processing Record 40 of Set 1 | taolanaro
# City not found, Skiping...
# Processing Record 41 of Set 1 | victoria
# City not found, Skiping...
# Processing Record 42 of Set 1 | knysna
# City not found, Skiping...
# Processing Record 43 of Set 1 | ushuaia
# City not found, Skiping...
# Processing Record 44 of Set 1 | cape town
# City not found, Skiping...
# Processing Record 45 of Set 1 | qui nhon
# City not found, Skiping...
# Processing Record 46 of Set 1 | kilindoni
# City not found, Skiping...
# Processing Record 47 of Set 1 | fukuma
# City not found, Skiping...
# Processing Record 48 of Set 1 | shenjiamen
# City not found, Skiping...
# Processing Record 49 of Set 1 | rio gallegos
# City not found, Skiping...
# Processing Record 50 of Set 1 | rikitea
# City not found, Skiping...
# Processing Record 0 of Set 2 | avera
# City not found, Skiping...
# Processing Record 1 of Set 2 | chokurdakh
# City not found, Skiping...
# Processing Record 2 of Set 2 | paamiut
# City not found, Skiping...
# Processing Record 3 of Set 2 | dikson
# City not found, Skiping...
# Processing Record 4 of Set 2 | mataura
# City not found, Skiping...
# Processing Record 5 of Set 2 | acurenam
# City not found, Skiping...
# Processing Record 6 of Set 2 | seekirchen
# City not found, Skiping...
# Processing Record 7 of Set 2 | marang
# City not found, Skiping...
# Processing Record 8 of Set 2 | fortuna
# City not found, Skiping...
# Processing Record 9 of Set 2 | georgetown
# City not found, Skiping...
# Processing Record 10 of Set 2 | waupun
# City not found, Skiping...
# Processing Record 11 of Set 2 | east london
# City not found, Skiping...
# Processing Record 12 of Set 2 | tuktoyaktuk
# City not found, Skiping...
# Processing Record 13 of Set 2 | atuona
# City not found, Skiping...
# Processing Record 14 of Set 2 | madison
# City not found, Skiping...
# Processing Record 15 of Set 2 | anloga
# City not found, Skiping...
# Processing Record 16 of Set 2 | hermanus
# City not found, Skiping...
# Processing Record 17 of Set 2 | strezhevoy
# City not found, Skiping...
# Processing Record 18 of Set 2 | lasa
# City not found, Skiping...
# Processing Record 19 of Set 2 | kijang
# City not found, Skiping...
# Processing Record 20 of Set 2 | abu zabad
# City not found, Skiping...
# Processing Record 21 of Set 2 | tasiilaq
# City not found, Skiping...
# Processing Record 22 of Set 2 | sao felix do xingu
# City not found, Skiping...
# Processing Record 23 of Set 2 | pangnirtung
# City not found, Skiping...
# Processing Record 24 of Set 2 | ejura
# City not found, Skiping...
# Processing Record 25 of Set 2 | hilo
# City not found, Skiping...
# Processing Record 26 of Set 2 | bethel
# City not found, Skiping...
# Processing Record 27 of Set 2 | realeza
# City not found, Skiping...
# Processing Record 28 of Set 2 | hobart
# City not found, Skiping...
# Processing Record 29 of Set 2 | sidney
# City not found, Skiping...
# Processing Record 30 of Set 2 | caluquembe
# City not found, Skiping...
# Processing Record 31 of Set 2 | yellowknife
# City not found, Skiping...
# Processing Record 32 of Set 2 | pevek
# City not found, Skiping...
# Processing Record 33 of Set 2 | caravelas
# City not found, Skiping...
# Processing Record 34 of Set 2 | port alfred
# City not found, Skiping...
# Processing Record 35 of Set 2 | dakar
# City not found, Skiping...
# Processing Record 36 of Set 2 | saint george
# City not found, Skiping...
# Processing Record 37 of Set 2 | leningradskiy
# City not found, Skiping...
# Processing Record 38 of Set 2 | provideniya
# City not found, Skiping...
# Processing Record 39 of Set 2 | naze
# City not found, Skiping...
# Processing Record 40 of Set 2 | vilani
# City not found, Skiping...
# Processing Record 41 of Set 2 | trairi
# City not found, Skiping...
# Processing Record 42 of Set 2 | alofi
# City not found, Skiping...
# Processing Record 43 of Set 2 | altay
# City not found, Skiping...
# Processing Record 44 of Set 2 | tarakan
# City not found, Skiping...
# Processing Record 45 of Set 2 | bucak
# City not found, Skiping...
# Processing Record 46 of Set 2 | terrak
# City not found, Skiping...
# Processing Record 47 of Set 2 | cabo san lucas
# City not found, Skiping...
# Processing Record 48 of Set 2 | talaya
# City not found, Skiping...
# Processing Record 49 of Set 2 | ancud
# City not found, Skiping...
# Processing Record 0 of Set 3 | paita
# City not found, Skiping...
# Processing Record 1 of Set 3 | kapaa
# City not found, Skiping...
# Processing Record 2 of Set 3 | smithers
# City not found, Skiping...
# Processing Record 3 of Set 3 | ahipara
# City not found, Skiping...
# Processing Record 4 of Set 3 | komsomolskiy
# City not found, Skiping...
# Processing Record 5 of Set 3 | larsnes
# City not found, Skiping...
# Processing Record 6 of Set 3 | batang berjuntai
# City not found, Skiping...
# Processing Record 7 of Set 3 | cidreira
# City not found, Skiping...
# Processing Record 8 of Set 3 | nikolskoye
# City not found, Skiping...
# Processing Record 9 of Set 3 | luderitz
# City not found, Skiping...
# Processing Record 10 of Set 3 | esperance
# City not found, Skiping...
# Processing Record 11 of Set 3 | mandera
# City not found, Skiping...
# Processing Record 12 of Set 3 | butaritari
# City not found, Skiping...
# Processing Record 13 of Set 3 | nuevitas
# City not found, Skiping...
# Processing Record 14 of Set 3 | souillac
# City not found, Skiping...
# Processing Record 15 of Set 3 | saint-augustin
# City not found, Skiping...
# Processing Record 16 of Set 3 | merritt
# City not found, Skiping...
# Processing Record 17 of Set 3 | guerrero negro
# City not found, Skiping...
# Processing Record 18 of Set 3 | shingu
# City not found, Skiping...
# Processing Record 19 of Set 3 | santiago del estero
# City not found, Skiping...
# Processing Record 20 of Set 3 | saint-philippe
# City not found, Skiping...
# Processing Record 21 of Set 3 | kodiak
# City not found, Skiping...
# Processing Record 22 of Set 3 | havelock
# City not found, Skiping...
# Processing Record 23 of Set 3 | phibun mangsahan
# City not found, Skiping...
# Processing Record 24 of Set 3 | saleaula
# City not found, Skiping...
# Processing Record 25 of Set 3 | riyadh
# City not found, Skiping...
# Processing Record 26 of Set 3 | cairns
# City not found, Skiping...
# Processing Record 27 of Set 3 | louisbourg
# City not found, Skiping...
# Processing Record 28 of Set 3 | aksarka
# City not found, Skiping...
# Processing Record 29 of Set 3 | puri
# City not found, Skiping...
# Processing Record 30 of Set 3 | hervey bay
# City not found, Skiping...
# Processing Record 31 of Set 3 | broken hill
# City not found, Skiping...
# Processing Record 32 of Set 3 | kitimat
# City not found, Skiping...
# Processing Record 33 of Set 3 | port lincoln
# City not found, Skiping...
# Processing Record 34 of Set 3 | tocopilla
# City not found, Skiping...
# Processing Record 35 of Set 3 | lincoln
# City not found, Skiping...
# Processing Record 36 of Set 3 | makakilo city
# City not found, Skiping...
# Processing Record 37 of Set 3 | ozuluama
# City not found, Skiping...
# Processing Record 38 of Set 3 | te anau
# City not found, Skiping...
# Processing Record 39 of Set 3 | tolaga bay
# City not found, Skiping...
# Processing Record 40 of Set 3 | ambodifototra
# City not found, Skiping...
# Processing Record 41 of Set 3 | kushiro
# City not found, Skiping...
# Processing Record 42 of Set 3 | general roca
# City not found, Skiping...
# Processing Record 43 of Set 3 | eydhafushi
# City not found, Skiping...
# Processing Record 44 of Set 3 | yeppoon
# City not found, Skiping...
# Processing Record 45 of Set 3 | namatanai
# City not found, Skiping...
# Processing Record 46 of Set 3 | maebaru
# City not found, Skiping...
# Processing Record 47 of Set 3 | bluff
# City not found, Skiping...
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found, Skiping...
# Processing Record 49 of Set 3 | eureka
# City not found, Skiping...
# Processing Record 0 of Set 4 | port-gentil
# City not found, Skiping...
# Processing Record 1 of Set 4 | itaparica
# City not found, Skiping...
# Processing Record 2 of Set 4 | cam pha
# City not found, Skiping...
# Processing Record 3 of Set 4 | umm kaddadah
# City not found, Skiping...
# Processing Record 4 of Set 4 | axim
# City not found, Skiping...
# Processing Record 5 of Set 4 | saint anthony
# City not found, Skiping...
# Processing Record 6 of Set 4 | doctor pedro p. pena
# City not found, Skiping...
# Processing Record 7 of Set 4 | la ronge
# City not found, Skiping...
# Processing Record 8 of Set 4 | thinadhoo
# City not found, Skiping...
# Processing Record 9 of Set 4 | wahran
# City not found, Skiping...
# Processing Record 10 of Set 4 | mayo
# City not found, Skiping...
# Processing Record 11 of Set 4 | trojan
# City not found, Skiping...
# Processing Record 12 of Set 4 | luganville
# City not found, Skiping...
# Processing Record 13 of Set 4 | salalah
# City not found, Skiping...
# Processing Record 14 of Set 4 | san cristobal
# City not found, Skiping...
# Processing Record 15 of Set 4 | palma del rio
# City not found, Skiping...
# Processing Record 16 of Set 4 | hamilton
# City not found, Skiping...
# Processing Record 17 of Set 4 | aleksandrovsk-sakhalinskiy
# City not found, Skiping...
# Processing Record 18 of Set 4 | barrow
# City not found, Skiping...
# Processing Record 19 of Set 4 | sakakah
# City not found, Skiping...
# Processing Record 20 of Set 4 | kulhudhuffushi
# City not found, Skiping...
# Processing Record 21 of Set 4 | lashio
# City not found, Skiping...
# Processing Record 22 of Set 4 | dale
# City not found, Skiping...
# Processing Record 23 of Set 4 | zarubino
# City not found, Skiping...
# Processing Record 24 of Set 4 | providencia
# City not found, Skiping...
# Processing Record 25 of Set 4 | kahului
# City not found, Skiping...
# Processing Record 26 of Set 4 | gorazde
# City not found, Skiping...
# Processing Record 27 of Set 4 | hualmay
# City not found, Skiping...
# Processing Record 28 of Set 4 | tsihombe
# City not found, Skiping...
# Processing Record 29 of Set 4 | urusha
# City not found, Skiping...
# Processing Record 30 of Set 4 | bambous virieux
# City not found, Skiping...
# Processing Record 31 of Set 4 | upernavik
# City not found, Skiping...
# Processing Record 32 of Set 4 | hami
# City not found, Skiping...
# Processing Record 33 of Set 4 | alindao
# City not found, Skiping...
# Processing Record 34 of Set 4 | pokhara
# City not found, Skiping...
# Processing Record 35 of Set 4 | tongliao
# City not found, Skiping...
# Processing Record 36 of Set 4 | guanica
# City not found, Skiping...
# Processing Record 37 of Set 4 | san patricio
# City not found, Skiping...
# Processing Record 38 of Set 4 | vanavara
# City not found, Skiping...
# Processing Record 39 of Set 4 | umzimvubu
# City not found, Skiping...
# Processing Record 40 of Set 4 | hirara
# City not found, Skiping...
# Processing Record 41 of Set 4 | hithadhoo
# City not found, Skiping...
# Processing Record 42 of Set 4 | nanortalik
# City not found, Skiping...
# Processing Record 43 of Set 4 | arona
# City not found, Skiping...
# Processing Record 44 of Set 4 | okhotsk
# City not found, Skiping...
# Processing Record 45 of Set 4 | callaway
# City not found, Skiping...
# Processing Record 46 of Set 4 | almaznyy
# City not found, Skiping...
# Processing Record 47 of Set 4 | kavieng
# City not found, Skiping...
# Processing Record 48 of Set 4 | pisco
# City not found, Skiping...
# Processing Record 49 of Set 4 | acari
# City not found, Skiping...
# Processing Record 0 of Set 5 | nishihara
# City not found, Skiping...
# Processing Record 1 of Set 5 | mazamari
# City not found, Skiping...
# Processing Record 2 of Set 5 | itarema
# City not found, Skiping...
# Processing Record 3 of Set 5 | asau
# City not found, Skiping...
# Processing Record 4 of Set 5 | shache
# City not found, Skiping...
# Processing Record 5 of Set 5 | puerto ayora
# City not found, Skiping...
# Processing Record 6 of Set 5 | vila velha
# City not found, Skiping...
# Processing Record 7 of Set 5 | kropotkin
# City not found, Skiping...
# Processing Record 8 of Set 5 | hashtrud
# City not found, Skiping...
# Processing Record 9 of Set 5 | attawapiskat
# City not found, Skiping...
# Processing Record 10 of Set 5 | vaitupu
# City not found, Skiping...
# Processing Record 11 of Set 5 | hermosillo
# City not found, Skiping...
# Processing Record 12 of Set 5 | road town
# City not found, Skiping...
# Processing Record 13 of Set 5 | klaksvik
# City not found, Skiping...
# Processing Record 14 of Set 5 | lolua
# City not found, Skiping...
# Processing Record 15 of Set 5 | bandarbeyla
# City not found, Skiping...
# Processing Record 16 of Set 5 | ewa beach
# City not found, Skiping...
# Processing Record 17 of Set 5 | chuy
# City not found, Skiping...
# Processing Record 18 of Set 5 | male
# City not found, Skiping...
# Processing Record 19 of Set 5 | qaanaaq
# City not found, Skiping...
# Processing Record 20 of Set 5 | conde
# City not found, Skiping...
# Processing Record 21 of Set 5 | imeni poliny osipenko
# City not found, Skiping...
# Processing Record 22 of Set 5 | andenes
# City not found, Skiping...
# Processing Record 23 of Set 5 | vaitape
# City not found, Skiping...
# Processing Record 24 of Set 5 | mandal
# City not found, Skiping...
# Processing Record 25 of Set 5 | mys shmidta
# City not found, Skiping...
# Processing Record 26 of Set 5 | lephepe
# City not found, Skiping...
# Processing Record 27 of Set 5 | lenoir
# City not found, Skiping...
# Processing Record 28 of Set 5 | hofn
# City not found, Skiping...
# Processing Record 29 of Set 5 | roma
# City not found, Skiping...
# Processing Record 30 of Set 5 | okha
# City not found, Skiping...
# Processing Record 31 of Set 5 | sentyabrskiy
# City not found, Skiping...
# Processing Record 32 of Set 5 | ribeira grande
# City not found, Skiping...
# Processing Record 33 of Set 5 | kuito
# City not found, Skiping...
# Processing Record 34 of Set 5 | orlik
# City not found, Skiping...
# Processing Record 35 of Set 5 | arraial do cabo
# City not found, Skiping...
# Processing Record 36 of Set 5 | tucurui
# City not found, Skiping...
# Processing Record 37 of Set 5 | shaowu
# City not found, Skiping...
# Processing Record 38 of Set 5 | berlevag
# City not found, Skiping...
# Processing Record 39 of Set 5 | gediz
# City not found, Skiping...
# Processing Record 40 of Set 5 | tiksi
# City not found, Skiping...
# Processing Record 41 of Set 5 | sonoita
# City not found, Skiping...
# Processing Record 42 of Set 5 | barcelona
# City not found, Skiping...
# Processing Record 43 of Set 5 | vengerovo
# City not found, Skiping...
# Processing Record 44 of Set 5 | hasaki
# City not found, Skiping...
# Processing Record 45 of Set 5 | constitucion
# City not found, Skiping...
# Processing Record 46 of Set 5 | huarmey
# City not found, Skiping...
# Processing Record 47 of Set 5 | fasa
# City not found, Skiping...
# Processing Record 48 of Set 5 | meulaboh
# City not found, Skiping...
# Processing Record 49 of Set 5 | altamont
# City not found, Skiping...
# Processing Record 0 of Set 6 | muros
# City not found, Skiping...
# Processing Record 1 of Set 6 | gambo
# City not found, Skiping...
# Processing Record 2 of Set 6 | mareeba
# City not found, Skiping...
# Processing Record 3 of Set 6 | port elizabeth
# City not found, Skiping...
# Processing Record 4 of Set 6 | labuhan
# City not found, Skiping...
# Processing Record 5 of Set 6 | ulladulla
# City not found, Skiping...
# Processing Record 6 of Set 6 | gurupi
# City not found, Skiping...
# Processing Record 7 of Set 6 | prince rupert
# City not found, Skiping...
# Processing Record 8 of Set 6 | the pas
# City not found, Skiping...
# Processing Record 9 of Set 6 | laibin
# City not found, Skiping...
# Processing Record 10 of Set 6 | kizukuri
# City not found, Skiping...
# Processing Record 11 of Set 6 | riyaq
# City not found, Skiping...
# Processing Record 12 of Set 6 | belmonte
# City not found, Skiping...
# Processing Record 13 of Set 6 | chagda
# City not found, Skiping...
# Processing Record 14 of Set 6 | vigrestad
# City not found, Skiping...
# Processing Record 15 of Set 6 | port blair
# City not found, Skiping...
# Processing Record 16 of Set 6 | husavik
# City not found, Skiping...
# Processing Record 17 of Set 6 | grand centre
# City not found, Skiping...
# Processing Record 18 of Set 6 | ongandjera
# City not found, Skiping...
# Processing Record 19 of Set 6 | yarmouth
# City not found, Skiping...
# Processing Record 20 of Set 6 | khasan
# City not found, Skiping...
# Processing Record 21 of Set 6 | gorontalo
# City not found, Skiping...
# Processing Record 22 of Set 6 | geraldton
# City not found, Skiping...
# Processing Record 23 of Set 6 | vardo
# City not found, Skiping...
# Processing Record 24 of Set 6 | srednekolymsk
# City not found, Skiping...
# Processing Record 25 of Set 6 | krasnoselkup
# City not found, Skiping...
# Processing Record 26 of Set 6 | tumannyy
# City not found, Skiping...
# Processing Record 27 of Set 6 | samusu
# City not found, Skiping...
# Processing Record 28 of Set 6 | wangaratta
# City not found, Skiping...
# Processing Record 29 of Set 6 | sitka
# City not found, Skiping...
# Processing Record 30 of Set 6 | dunedin
# City not found, Skiping...
# Processing Record 31 of Set 6 | takab
# City not found, Skiping...
# Processing Record 32 of Set 6 | inirida
# City not found, Skiping...
# Processing Record 33 of Set 6 | nuuk
# City not found, Skiping...
# Processing Record 34 of Set 6 | codrington
# City not found, Skiping...
# Processing Record 35 of Set 6 | lovington
# City not found, Skiping...
# Processing Record 36 of Set 6 | qandahar
# City not found, Skiping...
# Processing Record 37 of Set 6 | norden
# City not found, Skiping...
# Processing Record 38 of Set 6 | samut sakhon
# City not found, Skiping...
# Processing Record 39 of Set 6 | panzhihua
# City not found, Skiping...
# Processing Record 40 of Set 6 | buzdyak
# City not found, Skiping...
# Processing Record 41 of Set 6 | pomezia
# City not found, Skiping...
# Processing Record 42 of Set 6 | winnemucca
# City not found, Skiping...
# Processing Record 43 of Set 6 | matata
# City not found, Skiping...
# Processing Record 44 of Set 6 | ambanja
# City not found, Skiping...
# Processing Record 45 of Set 6 | tim
# City not found, Skiping...
# Processing Record 46 of Set 6 | mount isa
# City not found, Skiping...
# Processing Record 47 of Set 6 | khonuu
# City not found, Skiping...
# Processing Record 48 of Set 6 | sioux lookout
# City not found, Skiping...
# Processing Record 49 of Set 6 | marshall
# City not found, Skiping...
# Processing Record 0 of Set 7 | kruisfontein
# City not found, Skiping...
# Processing Record 1 of Set 7 | nemea
# City not found, Skiping...
# Processing Record 2 of Set 7 | poum
# City not found, Skiping...
# Processing Record 3 of Set 7 | moose factory
# City not found, Skiping...
# Processing Record 4 of Set 7 | mrirt
# City not found, Skiping...
# Processing Record 5 of Set 7 | moerai
# City not found, Skiping...
# Processing Record 6 of Set 7 | beringovskiy
# City not found, Skiping...
# Processing Record 7 of Set 7 | orcopampa
# City not found, Skiping...
# Processing Record 8 of Set 7 | flinders
# City not found, Skiping...
# Processing Record 9 of Set 7 | kysyl-syr
# City not found, Skiping...
# Processing Record 10 of Set 7 | nicoya
# City not found, Skiping...
# Processing Record 11 of Set 7 | juba
# City not found, Skiping...
# Processing Record 12 of Set 7 | kapuskasing
# City not found, Skiping...
# Processing Record 13 of Set 7 | sapa
# City not found, Skiping...
# Processing Record 14 of Set 7 | inta
# City not found, Skiping...
# Processing Record 15 of Set 7 | kirakira
# City not found, Skiping...
# Processing Record 16 of Set 7 | solsvik
# City not found, Skiping...
# Processing Record 17 of Set 7 | oil city
# City not found, Skiping...
# Processing Record 18 of Set 7 | iqaluit
# City not found, Skiping...
# Processing Record 19 of Set 7 | indiaroba
# City not found, Skiping...
# Processing Record 20 of Set 7 | mehamn
# City not found, Skiping...
# Processing Record 21 of Set 7 | palabuhanratu
# City not found, Skiping...
# Processing Record 22 of Set 7 | ilulissat
# City not found, Skiping...
# Processing Record 23 of Set 7 | baykit
# City not found, Skiping...
# Processing Record 24 of Set 7 | mar del plata

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
